# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import tensorflow as tf
! pip install tensorflow_addons
import tensorflow_addons as tfa
from keras.models import Sequential
# Out:
# Requirement already satisfied: tensorflow_addons in /usr/local/lib/python3.7/dist-packages (0.16.1)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (2.7.1)

# %% [markdown]
# Pre-process Data

# %%
import numpy as np
from skimage.util.shape import view_as_windows
from PIL import Image
from matplotlib import pyplot as plt
def preprocess_data():
  train = []
  traing = []
  test1=[]
  test1g=[]
  test2=[]
  test2g=[]
  for i in range(1,401):
    imgName=''
    if i<100:
      if i<10:
        imgName='00'+str(i)
      else:
        imgName='0'+str(i)
    else:
      imgName=str(i)
    # varun path - /content/drive/MyDrive/SMAI/Project/train400/test_
    file = "/content/drive/MyDrive/Colab Notebooks/SMAI /Project/train400/test_"+imgName+".png"
    image = Image.open(file)
    image = np.asarray(image)
    t = view_as_windows(image, (50,50), step=30).reshape((-1,50,50)) 
    # print(t.shape) 
    train.append(t)

  for i in range(1,8):
    imgName=''
    if i<10:
      imgName='0'+str(i)
    else:
      imgName=str(i)
    file = "/content/drive/MyDrive/Colab Notebooks/SMAI /Project/set12/"+imgName+".png"
    image = Image.open(file)
    image = np.asarray(image)
    t = view_as_windows(image, (50,50), step=50).reshape((-1,50,50))  
    test1.append(t)

  for i in range(8,13):
    imgName=''
    if i<10:
      imgName='0'+str(i)
    else:
      imgName=str(i)
    file = "/content/drive/MyDrive/Colab Notebooks/SMAI /Project/set12/"+imgName+".png"
    image = Image.open(file)
    image = np.asarray(image)  
    t = view_as_windows(image, (50,50), step=50).reshape((-1,50,50))
    test2.append(t)

  train =  np.array(train).reshape((-1,50,50))
  test1 =  np.array(test1).reshape((-1,50,50))
  test2 =  np.array(test2).reshape((-1,50,50))

  mean = 0
  sigma = 50

  gauss_noise = np.random.normal(mean,sigma,(50,50))

  traing = train + gauss_noise
  test1g = test1 + gauss_noise
  test2g = test2 + gauss_noise

  train = train/255.0
  traing = traing/255.0
  test1=test1/255.0
  test1g=test1g/255.0
  test2=test2/255.0
  test2g=test2g/255.0

  for i in range(4):
    plt.imshow(train[i],cmap='gray')
    plt.show()
    plt.imshow(traing[i],cmap='gray')
    plt.show()
  for i in range(4):
    plt.imshow(test1[i],cmap='gray')
    plt.show()
    plt.imshow(test1g[i],cmap='gray')
    plt.show()
  
  return train,traing,test1,test1g,test2,test2g

# %%
# from sklearn.model_selection import train_test_split

# data, datag = preprocess_data()


# traing, testg, train, test =  train_test_split(datag, data, test_size=0.25, shuffle=True)
train,traing,test1,test1g,test2,test2g=preprocess_data()
train = np.expand_dims(train,axis=-1)
traing = np.expand_dims(traing,axis=-1)
test1 = np.expand_dims(test1,axis=-1)
test1g = np.expand_dims(test1g,axis=-1)
test2 = np.expand_dims(test2,axis=-1)
test2g = np.expand_dims(test2g,axis=-1)
print(train.shape,traing.shape, test1.shape, test1g.shape,test2.shape, test2g.shape)
# Out:
# (10000, 50, 50, 1) (10000, 50, 50, 1) (175, 50, 50, 1) (175, 50, 50, 1) (500, 50, 50, 1) (500, 50, 50, 1)

# %%
print(train.shape,traing.shape, test1.shape, test1g.shape,test2.shape, test2g.shape)
# Out:
# (10000, 50, 50, 1) (10000, 50, 50, 1) (175, 50, 50, 1) (175, 50, 50, 1) (500, 50, 50, 1) (500, 50, 50, 1)

# %% [markdown]
# ###Define Model

# %%
class FeatureExtraction(tf.keras.Model):
  def __init__(self):
    super(FeatureExtraction,self).__init__()
    self.conv_block_up=tf.keras.layers.Conv2D(8,(3,3), padding="same", strides=1, activation="relu")
    self.dilated_conv_block_up=tf.keras.layers.Conv2D(8,(3,3), padding="same", strides=1, dilation_rate=2,activation="relu")

    self.conv_block_down=tf.keras.layers.Conv2D(8,(3,3), padding="same", strides=1, activation="relu")
    self.dilated_conv_block_down=tf.keras.layers.Conv2D(8,(3,3), padding="same", strides=1, dilation_rate=2,activation="relu")

  def call(self,input_tensor):
    x=self.conv_block_up(input_tensor)
    y=self.dilated_conv_block_up(x)
    z=self.dilated_conv_block_down(input_tensor)
    a=self.conv_block_down(z)

    return tf.keras.layers.Add()([x,y,z,a])

# %%
class FeatureIntegration(tf.keras.Model):
  def __init__(self):
    super(FeatureIntegration,self).__init__()
    self.conv_block_first=tf.keras.layers.Conv2D(1,(1,1), strides=1,padding="same", activation="relu")
    self.conv_block_up=tf.keras.layers.Conv2D(8,(3,3), strides=1,padding="same", activation="relu")
    self.dilated_conv_block_up=tf.keras.layers.Conv2D(8,(3,3),dilation_rate=2,padding="same",activation="relu")
    self.conv_block_down=tf.keras.layers.Conv2D(8,(3,3), strides=1,padding="same", activation="relu")
    self.dilated_conv_block_down=tf.keras.layers.Conv2D(8,(3,3),dilation_rate=2,padding="same",activation="relu")
    self.conv_block_second=tf.keras.layers.Conv2D(1,(1,1), strides=1,padding="same", activation="relu")
  def call(self,input_tensor):
    b=self.conv_block_first(input_tensor)
    x=self.conv_block_up(b)
    y=self.dilated_conv_block_up(x)
    z=self.dilated_conv_block_down(b)
    a=self.conv_block_down(z)
    add_first=tf.keras.layers.Add()([x,y,z,a])
    f=self.conv_block_second(add_first)
    return tf.keras.layers.Add()([f,input_tensor])

# %%
class Reconstruction(tf.keras.Model):
  def __init__(self):
    super(Reconstruction,self).__init__()
    self.conv_block_first=tf.keras.layers.Conv2D(1,(1,1), strides=1,padding="same", activation="sigmoid")
  def call(self,input_tensor):
    b=self.conv_block_first(input_tensor)
    return b

# %% [markdown]
# ###Build Model

# %%
from keras.models import Sequential

model = Sequential()

model.add(FeatureExtraction())

model.add(FeatureIntegration())
model.add(FeatureIntegration())
model.add(FeatureIntegration())
model.add(FeatureIntegration())
model.add(FeatureIntegration())
model.add(FeatureIntegration())
model.add(FeatureIntegration())
model.add(FeatureIntegration())

model.add(Reconstruction())

# opt=tf.keras.optimizers.Adam(
#     learning_rate=0.001,
#     name='Adam',
# )
opt= tfa.optimizers.AdamW(
    weight_decay=0.9,
    learning_rate= 0.001,
    name= 'AdamW',

)
model.compile(loss='mse')


results = model.fit(traing, train, epochs=100, verbose=1,batch_size=64)

model.summary()
# Out:
# Epoch 1/100
# 157/157 [==============================] - 16s 67ms/step - loss: 0.0249
# Epoch 2/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0094
# Epoch 3/100
# 157/157 [==============================] - 11s 69ms/step - loss: 0.0073
# Epoch 4/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0065
# Epoch 5/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0059
# Epoch 6/100
# 157/157 [==============================] - 11s 67ms/step - loss: 0.0054
# Epoch 7/100
# 157/157 [==============================] - 11s 67ms/step - loss: 0.0052
# Epoch 8/100
# 157/157 [==============================] - 11s 67ms/step - loss: 0.0049
# Epoch 9/100
# 157/157 [==============================] - 11s 67ms/step - loss: 0.0047
# Epoch 10/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0046
# Epoch 11/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0045
# Epoch 12/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0044
# Epoch 13/100
# 157/157 [==============================] - 11s 67ms/step - loss: 0.0043
# Epoch 14/100
# 157/157 [==============================] - 11s 67ms/step - loss: 0.0042
# Epoch 15/100
# 157/157 [==============================] - 11s 67ms/step - loss: 0.0042
# Epoch 16/100
# 157/157 [==============================] - 11s 67ms/step - loss: 0.0041
# Epoch 17/100
# 157/157 [==============================] - 11s 67ms/step - loss: 0.0041
# Epoch 18/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0040
# Epoch 19/100
# 157/157 [==============================] - 11s 67ms/step - loss: 0.0040
# Epoch 20/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0039
# Epoch 21/100
# 157/157 [==============================] - 11s 67ms/step - loss: 0.0039
# Epoch 22/100
# 157/157 [==============================] - 11s 67ms/step - loss: 0.0039
# Epoch 23/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0038
# Epoch 24/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0038
# Epoch 25/100
# 157/157 [==============================] - 11s 67ms/step - loss: 0.0038
# Epoch 26/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0038
# Epoch 27/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0037
# Epoch 28/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0037
# Epoch 29/100
# 157/157 [==============================] - 11s 67ms/step - loss: 0.0037
# Epoch 30/100
# 157/157 [==============================] - 11s 67ms/step - loss: 0.0036
# Epoch 31/100
# 157/157 [==============================] - 11s 67ms/step - loss: 0.0036
# Epoch 32/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0036
# Epoch 33/100
# 157/157 [==============================] - 11s 67ms/step - loss: 0.0036
# Epoch 34/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0035
# Epoch 35/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0035
# Epoch 36/100
# 157/157 [==============================] - 11s 67ms/step - loss: 0.0035
# Epoch 37/100
# 157/157 [==============================] - 11s 67ms/step - loss: 0.0035
# Epoch 38/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0035
# Epoch 39/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0034
# Epoch 40/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0034
# Epoch 41/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0034
# Epoch 42/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0034
# Epoch 43/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0034
# Epoch 44/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0033
# Epoch 45/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0033
# Epoch 46/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0033
# Epoch 47/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0033
# Epoch 48/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0032
# Epoch 49/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0032
# Epoch 50/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0032
# Epoch 51/100
# 157/157 [==============================] - 11s 67ms/step - loss: 0.0032
# Epoch 52/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0032
# Epoch 53/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0032
# Epoch 54/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0031
# Epoch 55/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0031
# Epoch 56/100
# 157/157 [==============================] - 11s 67ms/step - loss: 0.0031
# Epoch 57/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0031
# Epoch 58/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0031
# Epoch 59/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0030
# Epoch 60/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0030
# Epoch 61/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0030
# Epoch 62/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0030
# Epoch 63/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0030
# Epoch 64/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0030
# Epoch 65/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0029
# Epoch 66/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0029
# Epoch 67/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0029
# Epoch 68/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0029
# Epoch 69/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0029
# Epoch 70/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0029
# Epoch 71/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0029
# Epoch 72/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0028
# Epoch 73/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0028
# Epoch 74/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0028
# Epoch 75/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0028
# Epoch 76/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0028
# Epoch 77/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0028
# Epoch 78/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0027
# Epoch 79/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0027
# Epoch 80/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0027
# Epoch 81/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0027
# Epoch 82/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0027
# Epoch 83/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0027
# Epoch 84/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0027
# Epoch 85/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0027
# Epoch 86/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0026
# Epoch 87/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0026
# Epoch 88/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0026
# Epoch 89/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0026
# Epoch 90/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0026
# Epoch 91/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0026
# Epoch 92/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0026
# Epoch 93/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0026
# Epoch 94/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0025
# Epoch 95/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0025
# Epoch 96/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0025
# Epoch 97/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0025
# Epoch 98/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0025
# Epoch 99/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0025
# Epoch 100/100
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0025
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  feature_extraction_2 (Featu  (None, 50, 50, 8)        1328
#  reExtraction)
#
#  feature_integration_16 (Fea  (None, 50, 50, 8)        1346
#  tureIntegration)
#
#  feature_integration_17 (Fea  (None, 50, 50, 8)        1346
#  tureIntegration)
#
#  feature_integration_18 (Fea  (None, 50, 50, 8)        1346
#  tureIntegration)
#
#  feature_integration_19 (Fea  (None, 50, 50, 8)        1346
#  tureIntegration)
#
#  feature_integration_20 (Fea  (None, 50, 50, 8)        1346
#  tureIntegration)
#
#  feature_integration_21 (Fea  (None, 50, 50, 8)        1346
#  tureIntegration)
#
#  feature_integration_22 (Fea  (None, 50, 50, 8)        1346
#  tureIntegration)
#
#  feature_integration_23 (Fea  (None, 50, 50, 8)        1346
#  tureIntegration)
#
#  reconstruction_2 (Reconstru  (None, 50, 50, 1)        9
#  ction)
#
# =================================================================
# Total params: 12,105
# Trainable params: 12,105
# Non-trainable params: 0
# _________________________________________________________________

# %%
import pickle
# with open('/content/drive/MyDrive/Colab Notebooks/SMAI /Project/model_500.pickle', 'wb') as f:
#     pickle.dump(model, f)

# with open('/content/drive/MyDrive/Colab Notebooks/SMAI /Project/model_500.pickle', 'rb') as f:
#     model = pickle.load(f)
# Out:
# INFO:tensorflow:Assets written to: ram://9df2cf48-8f21-4c02-b814-b4a402a8c126/assets

# %%
import numpy as np
from math import log2, log10

def _initial_check(GT,P):
	assert GT.shape == P.shape, "Supplied images have different sizes " + \
	str(GT.shape) + " and " + str(P.shape)
	if GT.dtype != P.dtype:
		msg = "Supplied images have different dtypes " + \
			str(GT.dtype) + " and " + str(P.dtype)
		print(msg)
	

	if len(GT.shape) == 2:
		GT = GT[:,:,np.newaxis]
		P = P[:,:,np.newaxis]

	return GT.astype(np.float64),P.astype(np.float64)

def mse (GT,P):
	"""calculates mean squared error (mse).

	:param GT: first (original) input image.
	:param P: second (deformed) input image.

	:returns:  float -- mse value.
	"""
	GT,P = _initial_check(GT,P)
	return np.mean((GT.astype(np.float64)-P.astype(np.float64))**2)

def psnr (GT,P,MAX=None):
	"""calculates peak signal-to-noise ratio (psnr).

	:param GT: first (original) input image.
	:param P: second (deformed) input image.
	:param MAX: maximum value of datarange (if None, MAX is calculated using image dtype).

	:returns:  float -- psnr value in dB.
	"""
	if MAX is None:
		MAX = np.iinfo(GT.dtype).max

	GT,P = _initial_check(GT,P)

	mse_value = mse(GT,P)
	if mse_value == 0.:
		return np.inf
	return 10 * np.log10(MAX**2 /mse_value)

# %%
pred1 = model(test1g)
pred2 = model(test2g)
# print(pred.shape,test.shape)


mseloss1 = (7/12)*np.mean((pred1-test1)**2)+(5/12)*np.mean((pred2-test2)**2)
mseloss2 = (1/2)*np.mean((pred1-test1)**2)+(1/2)*np.mean((pred2-test2)**2)

# mseloss = np.mean((pred.astype(np.float64)-P.astype(np.float64))**2)
psnr_1 =   10*np.log10(1/mseloss1)
psnr_2 =   10*np.log10(1/mseloss2)
print("psnr with model",psnr_1)
print("psnr with model",psnr_2)
# Out:
# psnr with model 27.66563324617414
# psnr with model 27.71659671142157

# %%
ind=100

plt.imshow(np.squeeze(test1g[ind],(-1)),cmap='gray')
plt.show()

plt.imshow(np.squeeze(test1[ind],(-1)),cmap='gray')
plt.show()

temp = np.expand_dims(test1g[ind],axis=0)

pred = model(temp)

pred = np.squeeze(pred,(0,-1))

plt.imshow(pred*256,cmap='gray')
plt.show()

# %%
test1g[20],pred1

# %%
test1[20].shape,pred.shape
pred=y = np.expand_dims(pred,-1)
test1[20].shape,pred.shape
# Out:
# ((180, 180, 1), (180, 180, 1))

# %%
print("psnr with added gaussian noise",psnr(test1[20],test1g[20],1))
print("psnr with predicted",psnr(test1[20],pred,1))
# Out:
# psnr with added gaussian noise 20.139722697513914
# Supplied images have different dtypes float64 and float32
# psnr with predicted 24.22030384011249

# %% [markdown]
# ###DBF without wide (N layers)

# %%
class FeatureExtraction(tf.keras.Model):
  def __init__(self):
    super(FeatureExtraction,self).__init__()
    self.conv_block_up=tf.keras.layers.Conv2D(16,(3,3), padding="same", strides=1, activation="relu")
    self.dilated_conv_block_up=tf.keras.layers.Conv2D(16,(3,3), padding="same", strides=1, dilation_rate=2,activation="relu")

  def call(self,input_tensor):
    x=self.conv_block_up(input_tensor)
    y=self.dilated_conv_block_up(x)
    return tf.keras.layers.Add()([x,y])

# %%
class FeatureIntegration(tf.keras.Model):
  def __init__(self):
    super(FeatureIntegration,self).__init__()
    self.conv_block_first=tf.keras.layers.Conv2D(32,(1,1), strides=1,padding="same", activation="relu")
    #self.conv_block_up=tf.keras.layers.Conv2D(6,(3,3), strides=1,padding="same", activation="relu")
    self.dilated_conv_block_up=tf.keras.layers.Conv2D(8,(3,3),dilation_rate=2,padding="same",activation="relu")
    
  def call(self,input_tensor):
    b=self.conv_block_first(input_tensor)
    y=self.dilated_conv_block_up(b)
    return tf.keras.layers.Add()([input_tensor,y])

# %%
class Reconstruction(tf.keras.Model):
  def __init__(self):
    super(Reconstruction,self).__init__()
    self.conv_block_first=tf.keras.layers.Conv2D(1,(1,1), strides=1,padding="same", activation="sigmoid")
  def call(self,input_tensor):
    b=self.conv_block_first(input_tensor)
    return b

# %%
def get_DBF_non_wide(N,train_x,train_y):
  model = Sequential()

  model.add(FeatureExtraction())

  # for i in range(N):
  model.add(FeatureIntegration())
  model.add(FeatureIntegration())
  model.add(FeatureIntegration())

  model.add(Reconstruction())

  # opt = tfa.optimizers.SGDW(
  #     weight_decay = 0.0001,
  #     learning_rate =  0.001,
  #     momentum = 0.9,
  # )

  model.compile(optimizer="adam", loss='mse')

  results = model.fit(train_x,train_y, epochs=100, verbose=1)

  model.summary()
  return model

# %%
model3=get_DBF_non_wide(3,traing,train)
# model5=get_DBF_non_wide(5)
# model8=get_DBF_non_wide(8)
pred1 = model3(test1g)
pred2 = model3(test2g)
# print(pred.shape,test.shape)


mseloss1 = (7/12)*np.mean((pred1-test1)**2)+(5/12)*np.mean((pred2-test2)**2)
mseloss2 = (1/2)*np.mean((pred1-test1)**2)+(1/2)*np.mean((pred2-test2)**2)

# mseloss = np.mean((pred.astype(np.float64)-P.astype(np.float64))**2)
psnr_1 =   10*np.log10(1/mseloss1)
psnr_2 =   10*np.log10(1/mseloss2)
print("psnr with model",psnr_1)
print("psnr with model",psnr_2)
# Out:
# Epoch 1/100
# 13/13 [==============================] - 7s 362ms/step - loss: 0.0599
# Epoch 2/100
# 13/13 [==============================] - 5s 358ms/step - loss: 0.0474
# Epoch 3/100
# 13/13 [==============================] - 5s 360ms/step - loss: 0.0349
# Epoch 4/100
# 13/13 [==============================] - 5s 359ms/step - loss: 0.0213
# Epoch 5/100
# 13/13 [==============================] - 5s 360ms/step - loss: 0.0118
# Epoch 6/100
# 13/13 [==============================] - 5s 360ms/step - loss: 0.0088
# Epoch 7/100
# 13/13 [==============================] - 5s 363ms/step - loss: 0.0077
# Epoch 8/100
# 13/13 [==============================] - 5s 359ms/step - loss: 0.0070
# Epoch 9/100
# 13/13 [==============================] - 5s 360ms/step - loss: 0.0065
# Epoch 10/100
# 13/13 [==============================] - 5s 359ms/step - loss: 0.0061
# Epoch 11/100
# 13/13 [==============================] - 5s 360ms/step - loss: 0.0059
# Epoch 12/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0057
# Epoch 13/100
# 13/13 [==============================] - 5s 359ms/step - loss: 0.0056
# Epoch 14/100
# 13/13 [==============================] - 5s 360ms/step - loss: 0.0055
# Epoch 15/100
# 13/13 [==============================] - 5s 360ms/step - loss: 0.0054
# Epoch 16/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0054
# Epoch 17/100
# 13/13 [==============================] - 5s 360ms/step - loss: 0.0053
# Epoch 18/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0052
# Epoch 19/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0052
# Epoch 20/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0051
# Epoch 21/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0051
# Epoch 22/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0050
# Epoch 23/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0050
# Epoch 24/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0050
# Epoch 25/100
# 13/13 [==============================] - 5s 360ms/step - loss: 0.0049
# Epoch 26/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0049
# Epoch 27/100
# 13/13 [==============================] - 5s 362ms/step - loss: 0.0049
# Epoch 28/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0048
# Epoch 29/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0048
# Epoch 30/100
# 13/13 [==============================] - 5s 359ms/step - loss: 0.0048
# Epoch 31/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0047
# Epoch 32/100
# 13/13 [==============================] - 5s 360ms/step - loss: 0.0047
# Epoch 33/100
# 13/13 [==============================] - 5s 360ms/step - loss: 0.0047
# Epoch 34/100
# 13/13 [==============================] - 5s 360ms/step - loss: 0.0047
# Epoch 35/100
# 13/13 [==============================] - 5s 360ms/step - loss: 0.0046
# Epoch 36/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0046
# Epoch 37/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0046
# Epoch 38/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0046
# Epoch 39/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0046
# Epoch 40/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0045
# Epoch 41/100
# 13/13 [==============================] - 5s 360ms/step - loss: 0.0045
# Epoch 42/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0045
# Epoch 43/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0045
# Epoch 44/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0045
# Epoch 45/100
# 13/13 [==============================] - 5s 359ms/step - loss: 0.0045
# Epoch 46/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0045
# Epoch 47/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0044
# Epoch 48/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0044
# Epoch 49/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0044
# Epoch 50/100
# 13/13 [==============================] - 5s 360ms/step - loss: 0.0044
# Epoch 51/100
# 13/13 [==============================] - 5s 360ms/step - loss: 0.0044
# Epoch 52/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0044
# Epoch 53/100
# 13/13 [==============================] - 5s 360ms/step - loss: 0.0044
# Epoch 54/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0043
# Epoch 55/100
# 13/13 [==============================] - 5s 360ms/step - loss: 0.0043
# Epoch 56/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0043
# Epoch 57/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0043
# Epoch 58/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0043
# Epoch 59/100
# 13/13 [==============================] - 5s 362ms/step - loss: 0.0043
# Epoch 60/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0043
# Epoch 61/100
# 13/13 [==============================] - 5s 360ms/step - loss: 0.0043
# Epoch 62/100
# 13/13 [==============================] - 5s 360ms/step - loss: 0.0043
# Epoch 63/100
# 13/13 [==============================] - 5s 360ms/step - loss: 0.0043
# Epoch 64/100
# 13/13 [==============================] - 5s 360ms/step - loss: 0.0042
# Epoch 65/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0042
# Epoch 66/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0042
# Epoch 67/100
# 13/13 [==============================] - 5s 360ms/step - loss: 0.0042
# Epoch 68/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0042
# Epoch 69/100
# 13/13 [==============================] - 5s 360ms/step - loss: 0.0042
# Epoch 70/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0042
# Epoch 71/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0042
# Epoch 72/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0042
# Epoch 73/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0042
# Epoch 74/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0042
# Epoch 75/100
# 13/13 [==============================] - 5s 360ms/step - loss: 0.0042
# Epoch 76/100
# 13/13 [==============================] - 5s 360ms/step - loss: 0.0042
# Epoch 77/100
# 13/13 [==============================] - 5s 362ms/step - loss: 0.0042
# Epoch 78/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0042
# Epoch 79/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0042
# Epoch 80/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0041
# Epoch 81/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0041
# Epoch 82/100
# 13/13 [==============================] - 5s 360ms/step - loss: 0.0041
# Epoch 83/100
# 13/13 [==============================] - 5s 360ms/step - loss: 0.0041
# Epoch 84/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0041
# Epoch 85/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0041
# Epoch 86/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0041
# Epoch 87/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0041
# Epoch 88/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0041
# Epoch 89/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0041
# Epoch 90/100
# 13/13 [==============================] - 5s 360ms/step - loss: 0.0041
# Epoch 91/100
# 13/13 [==============================] - 5s 362ms/step - loss: 0.0041
# Epoch 92/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0041
# Epoch 93/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0041
# Epoch 94/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0041
# Epoch 95/100
# 13/13 [==============================] - 5s 360ms/step - loss: 0.0040
# Epoch 96/100
# 13/13 [==============================] - 5s 360ms/step - loss: 0.0041
# Epoch 97/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0040
# Epoch 98/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0040
# Epoch 99/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0040
# Epoch 100/100
# 13/13 [==============================] - 5s 361ms/step - loss: 0.0040
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  feature_extraction_3 (Featu  (None, 180, 180, 8)      1328
#  reExtraction)
#
#  feature_integration_14 (Fea  (None, 180, 180, 8)      1346
#  tureIntegration)
#
#  feature_integration_15 (Fea  (None, 180, 180, 8)      1346
#  tureIntegration)
#
#  feature_integration_16 (Fea  (None, 180, 180, 8)      1346
#  tureIntegration)
#
#  reconstruction_3 (Reconstru  (None, 180, 180, 1)      9
#  ction)
#
# =================================================================
# Total params: 5,375
# Trainable params: 5,375
# Non-trainable params: 0
# _________________________________________________________________
# psnr with model 24.762082680609822
# psnr with model 24.808523066290505
